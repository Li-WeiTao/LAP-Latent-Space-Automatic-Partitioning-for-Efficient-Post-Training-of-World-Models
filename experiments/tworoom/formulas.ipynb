# %% [markdown]
# # Gauge Drift 公式（编译预览）
#
# 运行下方代码 cell，会把每条公式渲染成高清 PNG 并内联显示。
#
# 符号：$S_i$ 状态 proxy，$Y_i$ encoder latent，$D$ 测试区域，$\mathrm{ref}$ / $\mathrm{train}$ 训练集全局 reference。

# %%
from render_formulas import show_all

show_all()
